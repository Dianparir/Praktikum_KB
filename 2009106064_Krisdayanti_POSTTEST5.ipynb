# %% [markdown]
# ## POSTTEST 5 Kecerdasan Buatan
# Nama : Krisdayanti
#
# NIM : 2009106064
#
# Kelas : KB B1'20
#
# link dataset https://www.kaggle.com/datasets/kekavigi/earthquakes-in-indonesia?resource=download

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from sklearn.metrics import classification_report, confusion_matrix

# %%
dataset = pd.read_csv('my_dataset\Earthquakes in Indonesia.csv')
dataset.head(5)
# Out:
#           tgl            ot   lat     lon  depth  mag  \
# 0  2008/11/01  21:02:43.058 -9.18  119.06     10  4.9
# 1  2008/11/01  20:58:50.248 -6.55  129.64     10  4.6
# 2  2008/11/01  17:43:12.941 -7.01  106.63    121  3.7
# 3  2008/11/01  16:24:14.755 -3.30  127.85     10  3.2
# 4  2008/11/01  16:20:37.327 -6.41  129.54     70  4.3
#
#                      remark  strike1  dip1  rake1  strike2  dip2  rake2
# 0  Sumba Region - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 1                 Banda Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 2          Java - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 3         Seram - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 4                 Banda Sea      NaN   NaN    NaN      NaN   NaN    NaN

# %%
dataset.head(5)
# Out:
#           tgl            ot   lat     lon  depth  mag  \
# 0  2008/11/01  21:02:43.058 -9.18  119.06     10  4.9
# 1  2008/11/01  20:58:50.248 -6.55  129.64     10  4.6
# 2  2008/11/01  17:43:12.941 -7.01  106.63    121  3.7
# 3  2008/11/01  16:24:14.755 -3.30  127.85     10  3.2
# 4  2008/11/01  16:20:37.327 -6.41  129.54     70  4.3
#
#                      remark  strike1  dip1  rake1  strike2  dip2  rake2
# 0  Sumba Region - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 1                 Banda Sea      NaN   NaN    NaN      NaN   NaN    NaN
# 2          Java - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 3         Seram - Indonesia      NaN   NaN    NaN      NaN   NaN    NaN
# 4                 Banda Sea      NaN   NaN    NaN      NaN   NaN    NaN

# %%
dataset.tail(5)
# Out:
#               tgl            ot    lat     lon  depth  mag  \
# 88584  2022/09/30  02:45:26.316  -0.02  123.59    108  3.5
# 88585  2022/09/30  00:55:25.665  -5.58  131.14    132  4.1
# 88586  2022/09/30  00:21:53.907 -10.34  124.75     10  3.8
# 88587  2022/09/30  00:17:02.868  -2.27  140.10     10  3.1
# 88588  2022/09/30  00:09:19.314  -0.20  122.95     32  3.0
#
#                                remark  strike1  dip1  rake1  strike2  dip2  \
# 88584  Minahassa Peninsula - Sulawesi      NaN   NaN    NaN      NaN   NaN
# 88585                       Banda Sea      NaN   NaN    NaN      NaN   NaN
# 88586                    Timor Region      NaN   NaN    NaN      NaN   NaN
# 88587  Near North Coast of Irian Jaya      NaN   NaN    NaN      NaN   NaN
# 88588  Minahassa Peninsula - Sulawesi      NaN   NaN    NaN      NaN   NaN
#
#        rake2
# 88584    NaN
# 88585    NaN
# 88586    NaN
# 88587    NaN
# 88588    NaN

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88589 entries, 0 to 88588
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tgl      88589 non-null  object
#  1   ot       88589 non-null  object
#  2   lat      88589 non-null  float64
#  3   lon      88589 non-null  float64
#  4   depth    88589 non-null  int64
#  5   mag      88589 non-null  float64
#  6   remark   88589 non-null  object
#  7   strike1  2581 non-null   float64
#  8   dip1     2581 non-null   float64
#  9   rake1    2581 non-null   float64
#  10  strike2  2581 non-null   float64
#  11  dip2     2581 non-null   float64
#  12  rake2    2581 non-null   float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 8.8+ MB

# %%
X = dataset[['lat', 'lon', 'depth', 'mag']] #data
Y = dataset['remark'] #label

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, shuffle=False, stratify=None)

# %% [markdown]
# ### Algoritma KNN

# %%
classifier_knn = KNeighborsClassifier(n_neighbors=5)

# %%
classifier_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
classifier_knn.score(X_test, y_test)
# Out:
# 0.8758352898681596

# %%
predicted_value = classifier_knn.predict(X_test)
accuracy = accuracy_score(y_test, predicted_value)

# %%
print(f'Hasil prediksi: {predicted_value}',
      f'Class: {y_test}',
      f'Akurasi: {accuracy}',
     sep = '\n'
)
# Out:
# Hasil prediksi: ['Northern Molucca Sea' 'Sunda Strait - Indonesia'
#  'Sumba Region - Indonesia' ... 'Timor Region'
#  'Near North Coast of Irian Jaya' 'Minahassa Peninsula - Sulawesi']
# Class: 66441             Halmahera - Indonesia
# 66442          Sunda Strait - Indonesia
# 66443          Sumba Region - Indonesia
# 66444         South of Bali - Indonesia
# 66445    Minahassa Peninsula - Sulawesi
#                       ...
# 88584    Minahassa Peninsula - Sulawesi
# 88585                         Banda Sea
# 88586                      Timor Region
# 88587    Near North Coast of Irian Jaya
# 88588    Minahassa Peninsula - Sulawesi
# Name: remark, Length: 22148, dtype: object
# Akurasi: 0.8758352898681596

# %% [markdown]
# ### Algoritma NAIVE BAYES

# %%
classifier_nb = GaussianNB()

# %%
classifier_nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
classifier_nb.score(X_test, y_test)
# Out:
# 0.8408885678165071

# %%
predicted_value = classifier_nb.predict(X_test)
accuracy = accuracy_score(y_test,predicted_value)

# %%
# from sklearn.metrics import classification_report, ConfusionMatrixDisplay
print(classification_report(y_test,predicted_value))
# Out:
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                     precision    recall  f1-score   support
#
#                        Arafura Sea       0.50      0.33      0.40         3
#     Aru Islands Region - Indonesia       0.68      0.64      0.66        33
# ...

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predicted_value)

# %% [markdown]
# ### Algoritma Support Vector Machine (SVM)

# %%
svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred = svclassifier.predict(X_test)

# %%
# from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[  3   0   0 ...   0   0   0]
#  [  0  28   0 ...   0   0   0]
#  [  0   0 148 ...   0   0   0]
#  ...
#  [  0   0   0 ... 434   0   0]
#  [  0   0   0 ...   3   8   0]
#  [  0   0   0 ...   0   0   4]]
# C:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                     precision    recall  f1-score   support
#
#                        Arafura Sea       0.75      1.00      0.86         3
#     Aru Islands Region - Indonesia       0.93      0.85      0.89        33
#            Bali Region - Indonesia       0.95      0.95      0.95       155
#                           Bali Sea       0.98      0.90      0.94       146
# ...

# %%
print('Training Accuracy :', svclassifier.score(X_train, y_train))
print('Testing Accuracy  :', svclassifier.score(X_test, y_test))
# Out:
# Training Accuracy : 0.9495492241236586
# Testing Accuracy  : 0.9468575040635724

# %%
ConfusionMatrixDisplay.from_predictions(y_test, predicted_value)
